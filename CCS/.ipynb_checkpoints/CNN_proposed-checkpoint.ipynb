# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.regularizers import l2
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config)

# %%
import os
def plot_imgs(directory, top=10):
    all_item_dirs = os.listdir(directory)
    item_files = [os.path.join(directory, file) for file in all_item_dirs][:5]
  
    plt.figure(figsize=(20, 20))
  
    for i, img_path in enumerate(item_files):
        plt.subplot(10, 10, i+1)
    
        img = plt.imread(img_path)
        plt.tight_layout()         
        plt.imshow(img, cmap='gray')

# %%
data_path = 'DataCNN/train/'

directories = ['ASC_H','ASC_US','HSIL','LSIL','SCC'] 

for j in directories:
    plot_imgs(data_path+j)

# %%
batch_size = 16
train_datagen = ImageDataGenerator(horizontal_flip = True, 
                                  rescale = 1./255, 
                                  # zoom_range = 0.2, 
                                  validation_split = 0.1)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
Categories=['ASC_H','ASC_US','HSIL','LSIL','SCC'] 
train_data_path = 'DataCNN/train/'
test_data_path = 'DataCNN/test/'

train_set = train_datagen.flow_from_directory(train_data_path, target_size = (56,56),
                                              batch_size = batch_size, 
                                              color_mode = 'rgba',
                                              class_mode = 'categorical',
                                             subset='training',
                                             shuffle="True")

valid_set = train_datagen.flow_from_directory(train_data_path, target_size = (56,56),
                                              batch_size = batch_size, 
                                              color_mode = 'rgba',
                                              class_mode = 'categorical',
                                             subset='validation',
                                             shuffle="True")

test_set = test_datagen.flow_from_directory(test_data_path, target_size = (56,56),
                                              batch_size = batch_size, 
                                              color_mode = 'rgba',
                                              class_mode = 'categorical')
# Out:
# Found 13608 images belonging to 5 classes.
# Found 1509 images belonging to 5 classes.
# Found 712 images belonging to 5 classes.

# %%
classes = 5

model = Sequential()
model.add(Conv2D(32, (3,3), padding = 'same', input_shape = (224,224,1), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64, (3,3), padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(128,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Flatten())
model.add(Dense(64, activation = 'relu'))

model.add(Dense(32, activation = 'relu'))
model.add(Dense(classes, activation = 'softmax'))

print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 224, 224, 32)      320
#
#  max_pooling2d_20 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 112, 112, 64)      18496
#
#  max_pooling2d_21 (MaxPoolin  (None, 56, 56, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 56, 56, 128)       73856
#
#  max_pooling2d_22 (MaxPoolin  (None, 28, 28, 128)      0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 100352)            0
#
#  dense_20 (Dense)            (None, 64)                6422592
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dense_22 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 6,517,509
# Trainable params: 6,517,509
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import keras
optimizer1 = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss = 'categorical_crossentropy',optimizer = "adam" , metrics = ['accuracy'])

# %%
model_path="saved_models/CNNProPosed.h5"

checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', verbose=1, 
                              save_best_only=True, mode='max')

callbacks_list = [checkpoint]

# %%
num_epochs = 30
training_steps=train_set.n//train_set.batch_size
validation_steps =test_set.n//test_set.batch_size

# %%
history = model.fit(train_set, epochs=num_epochs, steps_per_epoch=training_steps,validation_data=valid_set,
                    validation_steps=validation_steps, callbacks = callbacks_list)
# Out:
# Epoch 1/30
# 850/850 [==============================] - ETA: 0s - loss: 1.5235 - accuracy: 0.3002
# Epoch 1: val_accuracy improved from -inf to 0.29972, saving model to saved_models\CNNProPosed.h5
# 850/850 [==============================] - 77s 88ms/step - loss: 1.5235 - accuracy: 0.3002 - val_loss: 1.5307 - val_accuracy: 0.2997
# Epoch 2/30
# 850/850 [==============================] - ETA: 0s - loss: 1.4741 - accuracy: 0.3361
# Epoch 2: val_accuracy improved from 0.29972 to 0.30682, saving model to saved_models\CNNProPosed.h5
# 850/850 [==============================] - 72s 85ms/step - loss: 1.4741 - accuracy: 0.3361 - val_loss: 1.5154 - val_accuracy: 0.3068
# Epoch 3/30
# 850/850 [==============================] - ETA: 0s - loss: 1.4346 - accuracy: 0.3548
# Epoch 3: val_accuracy improved from 0.30682 to 0.32386, saving model to saved_models\CNNProPosed.h5
# 850/850 [==============================] - 81s 89ms/step - loss: 1.4346 - accuracy: 0.3548 - val_loss: 1.4993 - val_accuracy: 0.3239
# Epoch 4/30
# 850/850 [==============================] - ETA: 0s - loss: 1.3364 - accuracy: 0.4026
# Epoch 4: val_accuracy improved from 0.32386 to 0.38778, saving model to saved_models\CNNProPosed.h5
# 850/850 [==============================] - 75s 89ms/step - loss: 1.3364 - accuracy: 0.4026 - val_loss: 1.3211 - val_accuracy: 0.3878
# Epoch 5/30
# 850/850 [==============================] - ETA: 0s - loss: 1.2590 - accuracy: 0.4384
# Epoch 5: val_accuracy did not improve from 0.38778
# 850/850 [==============================] - 81s 95ms/step - loss: 1.2590 - accuracy: 0.4384 - val_loss: 1.3396 - val_accuracy: 0.3878
# Epoch 6/30
# 850/850 [==============================] - ETA: 0s - loss: 1.1845 - accuracy: 0.4795
# Epoch 6: val_accuracy improved from 0.38778 to 0.41619, saving model to saved_models\CNNProPosed.h5
# 850/850 [==============================] - 82s 96ms/step - loss: 1.1845 - accuracy: 0.4795 - val_loss: 1.2908 - val_accuracy: 0.4162
# Epoch 7/30
# 850/850 [==============================] - ETA: 0s - loss: 1.1128 - accuracy: 0.5145
# Epoch 7: val_accuracy did not improve from 0.41619
# 850/850 [==============================] - 76s 89ms/step - loss: 1.1128 - accuracy: 0.5145 - val_loss: 1.3475 - val_accuracy: 0.3821
# Epoch 8/30
# 850/850 [==============================] - ETA: 0s - loss: 1.0432 - accuracy: 0.5533
# Epoch 8: val_accuracy did not improve from 0.41619
# 850/850 [==============================] - 77s 90ms/step - loss: 1.0432 - accuracy: 0.5533 - val_loss: 1.5176 - val_accuracy: 0.3608
# Epoch 9/30
# 850/850 [==============================] - ETA: 0s - loss: 0.9568 - accuracy: 0.5998
# Epoch 9: val_accuracy improved from 0.41619 to 0.42898, saving model to saved_models\CNNProPosed.h5
# 850/850 [==============================] - 73s 86ms/step - loss: 0.9568 - accuracy: 0.5998 - val_loss: 1.4003 - val_accuracy: 0.4290
# Epoch 10/30
# 850/850 [==============================] - ETA: 0s - loss: 0.8868 - accuracy: 0.6315
# Epoch 10: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 75s 88ms/step - loss: 0.8868 - accuracy: 0.6315 - val_loss: 1.6576 - val_accuracy: 0.4020
# Epoch 11/30
# 850/850 [==============================] - ETA: 0s - loss: 0.8054 - accuracy: 0.6753
# Epoch 11: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 72s 85ms/step - loss: 0.8054 - accuracy: 0.6753 - val_loss: 1.5914 - val_accuracy: 0.4091
# Epoch 12/30
# 850/850 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.7195
# Epoch 12: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 77s 90ms/step - loss: 0.7055 - accuracy: 0.7195 - val_loss: 1.7857 - val_accuracy: 0.3991
# Epoch 13/30
# 850/850 [==============================] - ETA: 0s - loss: 0.6289 - accuracy: 0.7546
# Epoch 13: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 72s 84ms/step - loss: 0.6289 - accuracy: 0.7546 - val_loss: 1.9515 - val_accuracy: 0.3764
# Epoch 14/30
# 850/850 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.7898
# Epoch 14: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 75s 88ms/step - loss: 0.5475 - accuracy: 0.7898 - val_loss: 2.1346 - val_accuracy: 0.3977
# Epoch 15/30
# 850/850 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.8209
# Epoch 15: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 78s 92ms/step - loss: 0.4779 - accuracy: 0.8209 - val_loss: 2.3256 - val_accuracy: 0.3920
# Epoch 16/30
# 850/850 [==============================] - ETA: 0s - loss: 0.4172 - accuracy: 0.8456
# Epoch 16: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 74s 87ms/step - loss: 0.4172 - accuracy: 0.8456 - val_loss: 2.2290 - val_accuracy: 0.3920
# Epoch 17/30
# 850/850 [==============================] - ETA: 0s - loss: 0.3644 - accuracy: 0.8684
# Epoch 17: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 75s 89ms/step - loss: 0.3644 - accuracy: 0.8684 - val_loss: 2.9448 - val_accuracy: 0.3608
# Epoch 18/30
# 850/850 [==============================] - ETA: 0s - loss: 0.3281 - accuracy: 0.8877
# Epoch 18: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 74s 87ms/step - loss: 0.3281 - accuracy: 0.8877 - val_loss: 2.8025 - val_accuracy: 0.3963
# Epoch 19/30
# 850/850 [==============================] - ETA: 0s - loss: 0.2828 - accuracy: 0.8995
# Epoch 19: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 74s 87ms/step - loss: 0.2828 - accuracy: 0.8995 - val_loss: 2.8598 - val_accuracy: 0.3679
# Epoch 20/30
# 850/850 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.9112
# Epoch 20: val_accuracy did not improve from 0.42898
# 850/850 [==============================] - 74s 87ms/step - loss: 0.2524 - accuracy: 0.9112 - val_loss: 3.2005 - val_accuracy: 0.3835
# Epoch 21/30
# 129/850 [===>..........................] - ETA: 55s - loss: 0.2042 - accuracy: 0.9273
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 history = model.fit(train_set, epochs=num_epochs, steps_per_epoch=training_steps,validation_data=valid_set,
#       2                     validation_steps=validation_steps, callbacks = callbacks_list)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File D:\Anaconda\envs\DataScience\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : categorical_crossentropy', fontsize=10)
plt.ylabel('Giá trị mất mát', fontsize=16)
plt.plot(history.history['loss'], label='Độ mất mát huấn luyện')
plt.plot(history.history['val_loss'], label='Độ mất mát kiểm thử')
plt.legend(loc='upper right')
plt.subplot(1, 2, 2)
plt.ylabel('Độ chính xác', fontsize=16)
plt.plot(history.history['accuracy'], label='Độ chính xác huấn luyện')
plt.plot(history.history['val_accuracy'], label='Độ chính xác kiểm thử')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import seaborn as sns

def cm_cr(test_gen, model):
    preds=model.predict(test_gen)    
    labels=test_gen.labels
    classes=list(test_gen.class_indices.keys()) # ordered lst of class names 
    pred_list=[ ] # will store the predicted classes here
    true_list=[]
    for i, p in enumerate (preds):
        index=np.argmax(p)
        pred_list.append(classes[index])
        true_list.append(classes[labels[i]])
    y_pred=np.array(pred_list)
    y_true=np.array(true_list)
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)
    cm = confusion_matrix(y_true, y_pred )        
    length=len(classes)
    if length<8:
        fig_width=8
        fig_height=8
    else:
        fig_width= int(length * .5)
        fig_height= int(length * .5)
    plt.figure(figsize=(fig_width, fig_height))
    sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
    plt.xticks(np.arange(length)+.5, classes, rotation= 90, fontsize=16)
    plt.yticks(np.arange(length)+.5, classes, rotation=0, fontsize=16)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

cm_cr(test_set, model)
# Out:
# 45/45 [==============================] - 4s 85ms/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#        ASC_H       0.16      0.10      0.12       168
#       ASC_US       0.18      0.21      0.20       152
#         HSIL       0.15      0.22      0.18       128
#         LSIL       0.25      0.20      0.22       136
#          SCC       0.19      0.21      0.20       128
#
#     accuracy                           0.18       712
#    macro avg       0.19      0.19      0.18       712
# weighted avg       0.19      0.18      0.18       712
